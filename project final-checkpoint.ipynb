# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\USER\Downloads\datasets_14872_228180_Admission_Predict_Ver1.1 (1).csv")

# %%
dataset
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
dataset=dataset.drop('Serial No.',axis=1)

# %%
dataset
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
dataset.isnull().any()
# Out:
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %%
x=dataset.iloc[:,0:7].values
y=dataset.iloc[:,7:8].values

# %%
x.shape
# Out:
# (500, 7)

# %%
y.shape
# Out:
# (500, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=123)

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred= mlr.predict(x_test)

# %%
y_pred
# Out:
# array([[0.80768917],
#        [0.93479876],
#        [0.5303792 ],
#        [0.62362643],
#        [0.81791424],
#        [0.70034296],
#        [0.87583228],
#        [0.77662275],
#        [0.62056647],
#        [0.88393921],
#        [0.9027832 ],
#        [0.76428744],
#        [0.95259195],
#        [0.58724159],
#        [0.68995512],
#        [0.83581225],
#        [0.51867472],
#        [0.76866776],
#        [0.93862206],
#        [0.6202087 ],
#        [0.57358604],
#        [0.74972548],
#        [0.85217459],
#        [0.69107668],
#        [0.83084183],
#        [0.65173662],
#        [0.57996267],
#        [0.6273949 ],
#        [0.97410552],
#        [0.88120033],
#        [0.5342063 ],
#        [0.71343667],
#        [0.65787029],
#        [0.64879015],
#        [0.472998  ],
#        [0.8509634 ],
#        [0.85517134],
#        [0.7822117 ],
#        [0.94054506],
#        [0.61315557],
#        [0.63515053],
#        [0.72028865],
#        [0.66261675],
# ...

# %%
x_test
# Out:
# array([[324.  , 111.  ,   4.  ,   3.  ,   3.  ,   9.01,   1.  ],
#        [332.  , 118.  ,   5.  ,   5.  ,   5.  ,   9.47,   1.  ],
#        [295.  , 101.  ,   2.  ,   2.5 ,   2.  ,   7.86,   0.  ],
#        [315.  , 104.  ,   3.  ,   4.  ,   2.5 ,   8.1 ,   0.  ],
#        [323.  , 110.  ,   3.  ,   4.  ,   3.5 ,   9.1 ,   1.  ],
#        [303.  , 105.  ,   5.  ,   5.  ,   4.5 ,   8.65,   0.  ],
#        [330.  , 115.  ,   5.  ,   4.5 ,   3.  ,   9.34,   1.  ],
#        [320.  , 112.  ,   2.  ,   3.5 ,   3.5 ,   8.78,   1.  ],
#        [306.  , 103.  ,   3.  ,   3.5 ,   3.  ,   8.21,   0.  ],
#        [333.  , 113.  ,   5.  ,   4.  ,   4.  ,   9.28,   1.  ],
#        [329.  , 113.  ,   5.  ,   5.  ,   4.5 ,   9.45,   1.  ],
#        [325.  , 110.  ,   2.  ,   3.  ,   2.5 ,   8.76,   1.  ],
#        [331.  , 112.  ,   5.  ,   4.  ,   5.  ,   9.8 ,   1.  ],
#        [315.  , 100.  ,   1.  ,   2.  ,   2.5 ,   7.95,   0.  ],
# ...

# %%
from sklearn.metrics import r2_score
accuracy=r2_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.7787822431585506

# %%
dataset.head(1)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
#
#    Chance of Admit
# 0              0.92

# %%
y_p= mlr.predict([[337,118,4,4.5,4.5,9.65,1]])

# %%
y_p
# Out:
# array([[0.95689886]])

# %%
dataset.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=10,random_state=0)
rfr.fit(x_train,y_train)
# Out:
# D:\Users\USER\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
rfrpred=rfr.predict(x_test)

# %%
rfrpred
# Out:
# array([0.773, 0.939, 0.516, 0.673, 0.826, 0.651, 0.893, 0.754, 0.667,
#        0.904, 0.919, 0.765, 0.959, 0.584, 0.628, 0.817, 0.489, 0.743,
#        0.962, 0.635, 0.523, 0.756, 0.864, 0.704, 0.811, 0.64 , 0.513,
#        0.646, 0.94 , 0.896, 0.515, 0.702, 0.689, 0.635, 0.429, 0.873,
#        0.812, 0.767, 0.936, 0.628, 0.715, 0.677, 0.59 , 0.927, 0.797,
#        0.709, 0.697, 0.653, 0.963, 0.885, 0.791, 0.522, 0.562, 0.737,
#        0.517, 0.502, 0.716, 0.472, 0.555, 0.74 , 0.876, 0.902, 0.68 ,
#        0.513, 0.658, 0.912, 0.918, 0.837, 0.829, 0.906, 0.599, 0.708,
#        0.679, 0.822, 0.599, 0.932, 0.623, 0.505, 0.544, 0.676, 0.753,
#        0.529, 0.909, 0.783, 0.794, 0.778, 0.749, 0.565, 0.679, 0.689,
#        0.922, 0.896, 0.669, 0.87 , 0.673, 0.676, 0.646, 0.679, 0.798,
#        0.653])

# %%
rfraccuracy=r2_score(y_test,rfrpred)

# %%
rfraccuracy
# Out:
# 0.7380645898023992

# %%
dataset.head(10)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
# 5        330          115                  5  4.5   3.0  9.34         1
# 6        321          109                  3  3.0   4.0  8.20         1
# 7        308          101                  2  3.0   4.0  7.90         0
# 8        302          102                  1  2.0   1.5  8.00         0
# 9        323          108                  3  3.5   3.0  8.60         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65
# 5              0.90
# 6              0.75
# ...

# %%
y_p=rfr.predict([[308,101,2,3,4,7.9,0]])

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# D:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Users\USER\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
model=Sequential()
# Out:
# WARNING:tensorflow:From D:\Users\USER\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
x_train.shape
# Out:
# (400, 7)

# %%
model.add(Dense(units=7,init="random_uniform",activation="relu"))
# Out:
# D:\Users\USER\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=7, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=12,init="random_uniform",activation="relu"))
# Out:
# D:\Users\USER\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=12, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=1,init="random_uniform",activation="relu"))
# Out:
# D:\Users\USER\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.compile(optimizer="adam",loss="mean_squared_error",metrics=["mse"])
# Out:
# WARNING:tensorflow:From D:\Users\USER\anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x_train,y_train,epochs=500,batch_size=8)
# Out:
# WARNING:tensorflow:From D:\Users\USER\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Users\USER\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Users\USER\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Users\USER\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/500
# 400/400 [==============================] - 3s 7ms/step - loss: 0.3632 - mean_squared_error: 0.3632
# Epoch 2/500
# 400/400 [==============================] - 0s 305us/step - loss: 0.0198 - mean_squared_error: 0.0198
# ...

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[0.7762203 ],
#        [0.9250014 ],
#        [0.5356703 ],
#        [0.6205889 ],
#        [0.7870225 ],
#        [0.7229477 ],
#        [0.85174143],
#        [0.7607783 ],
#        [0.61916316],
#        [0.85310745],
#        [0.8821695 ],
#        [0.7258897 ],
#        [0.89876866],
#        [0.5457368 ],
#        [0.711141  ],
#        [0.81948674],
#        [0.505816  ],
#        [0.75439787],
#        [0.8905368 ],
#        [0.58269954],
#        [0.585937  ],
#        [0.71561813],
#        [0.8591571 ],
#        [0.6232375 ],
#        [0.8089638 ],
#        [0.6699836 ],
#        [0.5870477 ],
#        [0.5877069 ],
#        [0.94363093],
#        [0.87401736],
#        [0.53441155],
#        [0.688779  ],
#        [0.6138798 ],
#        [0.6593919 ],
#        [0.45643786],
#        [0.8607391 ],
#        [0.84377   ],
#        [0.7820642 ],
#        [0.8845899 ],
#        [0.6023948 ],
#        [0.60762715],
#        [0.6861417 ],
#        [0.6656648 ],
# ...

# %%
y_p=model.predict(np.array([[308,101,2,3,4,7.9,0]]))

# %%
y_p
# Out:
# array([[0.5942576]], dtype=float32)

# %%
from sklearn.metrics import r2_score
acc=r2_score(y_test,y_pred)

# %%
acc
# Out:
# 0.7722087523440606
